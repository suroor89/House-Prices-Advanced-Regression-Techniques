# %% [markdown]
# ## Build Model

# %% [markdown]
# #### XGBoost Model

# %%
import xgboost
import pandas as pd
import numpy as np
# to display all the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
df_train = pd.read_csv('X_train.csv')
df_test = pd.read_csv('test_new.csv')
col_names = ['SalePrice']
target_feature = pd.read_csv('target.csv',names=col_names, header=None)

# %%
df_train.shape, df_test.shape, target_feature.shape
# Out:
# ((1460, 21), (1459, 80), (1460, 1))

# %%
final_df = pd.concat([df_train,target_feature],axis=1)
final_df = pd.concat([final_df,df_test],axis=0)
# Out:
# /Users/suroor/Documents/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
final_df
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  Alley  BedroomAbvGr  BldgType  BsmtCond  \
# 0     0.356155       NaN        NaN    NaN           NaN       NaN       NaN
# 1     0.503056       NaN        NaN    NaN           NaN       NaN       NaN
# 2     0.383441       NaN        NaN    NaN           NaN       NaN       NaN
# 3     0.399941       NaN        NaN    NaN           NaN       NaN       NaN
# 4     0.466237       NaN        NaN    NaN           NaN       NaN       NaN
# ...        ...       ...        ...    ...           ...       ...       ...
# 1454  0.185992  0.264407        0.0    1.0         0.375      0.00      0.25
# 1455  0.185992  0.264407        0.0    1.0         0.375      0.25      0.25
# 1456  0.491486  0.000000        0.0    1.0         0.500      1.00      0.25
# 1457  0.403469  0.000000        0.0    1.0         0.375      1.00      0.25
# 1458  0.413479  0.486199        0.0    1.0         0.375      1.00      0.25
#
# ...

# %%
df_Train=final_df.iloc[:1460,:]
df_Test=final_df.iloc[1460:,:]

# %%
df_Train.shape, df_Test.shape
# Out:
# ((1460, 81), (1459, 81))

# %%
df_Train['SalePrice'].head()
# Out:
# 0    208500.0
# 1    181500.0
# 2    223500.0
# 3    140000.0
# 4    250000.0
# Name: SalePrice, dtype: float64

# %%
df_Test['SalePrice'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: SalePrice, dtype: float64

# %%
df_Test.drop(['SalePrice'],axis=1,inplace=True)
# Out:
# /Users/suroor/Documents/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X_train=df_Train.drop(['SalePrice'],axis=1)
y_train=df_Train['SalePrice']

# %%
classifier=xgboost.XGBRegressor()
regressor=xgboost.XGBRegressor()

# %%
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

## Hyper Parameter Optimization


n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
# Set up the random search with 4-fold cross validation
from sklearn.model_selection import RandomizedSearchCV
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)

# %%
random_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:   34.2s
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=4)]: Done 250 out of 250 | elapsed:  1.7min finished
# /Users/suroor/Documents/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/suroor/Documents/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [17:13:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
regressor=xgboost.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0,
             importance_type='gain', learning_rate=0.1, max_delta_step=0,
             max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
             n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
             silent=None, subsample=1, verbosity=1)

# %%
regressor.fit(X_train,y_train)
# Out:
# [17:13:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
import pickle
filename = 'trained_model.pkl'
pickle.dump(classifier, open(filename, 'wb'))

# %%
df_test.shape
# Out:
# (1459, 80)

# %%
y_pred=regressor.predict(df_Test)

# %%
y_pred
# Out:
# array([ 80282.56, 138706.45, 151551.03, ..., 141950.27,  94504.04,
#        211831.89], dtype=float32)

# %%
##Create Sample Submission file and Submit using ANN
pred = pd.DataFrame(y_pred)
submit_df = pd.read_csv('sample_submission.csv')
datasets = pd.concat([submit_df['Id'],pred],axis=1)
datasets.columns = ['Id','SalePrice']
datasets.to_csv('sample_submission.csv',index=False)

# %%
data = pd.read_csv('sample_submission.csv')

# %%
data.shape
# Out:
# (1459, 2)

# %%
target_feature.drop(target_feature.tail(1).index,inplace=True) # drop last n rows

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

kfold = KFold(n_splits=10, random_state=7)
results = cross_val_score(regressor, X_train, y_train, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

rmse = mean_squared_error(y_pred,target_feature)
print("RMSE: %f" % (rmse))
# Out:
# [17:13:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /Users/suroor/Documents/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [17:13:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /Users/suroor/Documents/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [17:13:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /Users/suroor/Documents/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
# ...
